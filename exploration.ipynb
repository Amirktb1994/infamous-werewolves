# %%
import pandas as pd
import seaborn as sb

# %%
df = pd.read_csv('data/processed/train.csv')

# %%
df2 = pd.read_csv('data/processed/valid.csv')

# %%
df
# Out:
#               load city  hour  day_name  weekday  day  month  year  dayofyear  \
# 0       263.365956   bs     0  Thursday        3    1      1  2015          1
# 1       259.073621   bs     1  Thursday        3    1      1  2015          1
# 2       246.612481   bs     2  Thursday        3    1      1  2015          1
# 3       238.313719   bs     3  Thursday        3    1      1  2015          1
# 4       237.114390   bs     4  Thursday        3    1      1  2015          1
# ...            ...  ...   ...       ...      ...  ...    ...   ...        ...
# 368251  322.822588   sz    19    Sunday        6   31     12  2017        365
# 368252  312.235274   sz    20    Sunday        6   31     12  2017        365
# 368253  317.510833   sz    21    Sunday        6   31     12  2017        365
# 368254  325.311059   sz    22    Sunday        6   31     12  2017        365
# 368255  309.321500   sz    23    Sunday        6   31     12  2017        365
#
# ...

# %%
df.load.hist()
# Out:
# <AxesSubplot:>

# %%
df.groupby('city')['load'].hist();

# %%
df.groupby('day_name')['load'].hist();

# %%
df.groupby(['city', 'day_name'])['load'].hist();

# %%
df.groupby('month')['load'].hist();

# %%
df.groupby('year')['load'].hist();

# %%
df.city.nunique()
# Out:
# 14

# %%
df[df.city == "bs"].set_index('dayofyear').groupby('year')['load'].plot()
# Out:
# year
# 2015    AxesSubplot(0.125,0.125;0.775x0.755)
# 2016    AxesSubplot(0.125,0.125;0.775x0.755)
# 2017    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: load, dtype: object

# %%
df[df.city == "bs"].set_index('dayofyear').groupby('year')['load'].plot()
# Out:
# year
# 2015    AxesSubplot(0.125,0.125;0.775x0.755)
# 2016    AxesSubplot(0.125,0.125;0.775x0.755)
# 2017    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: load, dtype: object

# %%
g = sb.FacetGrid(df, col='city', hue='year', col_wrap=4, sharey=False)
g = g.map(sb.lineplot, 'dayofyear', 'load', ci=None).add_legend()

# %%
df = pd.concat([df, df2])

# %%
g = sb.FacetGrid(df, col='city', hue='year', col_wrap=4, sharey=False)
g = g.map(sb.lineplot, 'dayofyear', 'load', ci=None).add_legend()

# %%
g
